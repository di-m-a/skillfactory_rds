# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import os
from collections import Counter
#print(os.listdir("../input"))

# %%
data = pd.read_csv(r'C:\Data for Python\data.csv')
data.head(5)
# Out:
#      imdb_id  popularity     budget     revenue                original_title  \
# 0  tt0369610   32.985763  150000000  1513528810                Jurassic World
# 1  tt1392190   28.419936  150000000   378436354            Mad Max: Fury Road
# 2  tt2908446   13.112507  110000000   295238201                     Insurgent
# 3  tt2488496   11.173104  200000000  2068178225  Star Wars: The Force Awakens
# 4  tt2820852    9.335014  190000000  1506249360                     Furious 7
#
#                                                 cast          director  \
# 0  Chris Pratt|Bryce Dallas Howard|Irrfan Khan|Vi...   Colin Trevorrow
# 1  Tom Hardy|Charlize Theron|Hugh Keays-Byrne|Nic...     George Miller
# 2  Shailene Woodley|Theo James|Kate Winslet|Ansel...  Robert Schwentke
# 3  Harrison Ford|Mark Hamill|Carrie Fisher|Adam D...       J.J. Abrams
# 4  Vin Diesel|Paul Walker|Jason Statham|Michelle ...         James Wan
#
#                          tagline  \
# ...

# %%
len(data)
# Out:
# 1890

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1890 entries, 0 to 1889
# Data columns (total 16 columns):
# imdb_id                 1890 non-null object
# popularity              1890 non-null float64
# budget                  1890 non-null int64
# revenue                 1890 non-null int64
# original_title          1890 non-null object
# cast                    1890 non-null object
# director                1890 non-null object
# tagline                 1890 non-null object
# overview                1890 non-null object
# runtime                 1890 non-null int64
# genres                  1890 non-null object
# production_companies    1890 non-null object
# release_date            1890 non-null object
# vote_count              1890 non-null int64
# vote_average            1890 non-null float64
# release_year            1890 non-null int64
# dtypes: float64(2), int64(5), object(9)
# memory usage: 236.4+ KB

# %%
data['profit'] = data.revenue - data.budget

# %% [markdown]
# # Предобработка датасета

# %%
answer_ls = [] # создадим список с ответами. сюда будем добавлять ответы по мере прохождения теста
# сюда можем вписать создание новых колонок в датасете

# %% [markdown]
# # 1. У какого фильма из списка самый большой бюджет?
# Варианты ответов:
# 1. The Dark Knight Rises (tt1345836)
# 2. Spider-Man 3 (tt0413300)
# 3. Avengers: Age of Ultron (tt2395427)
# 4. The Warrior's Way	(tt1032751)
# 5. Pirates of the Caribbean: On Stranger Tides (tt1298650)

# %%
data.loc[:,['budget','original_title']].sort_values(by = ['budget'],ascending=False).head(10)
# Out:
#          budget                               original_title
# 491   425000000                            The Warrior's Way
# 724   380000000  Pirates of the Caribbean: On Stranger Tides
# 1670  300000000     Pirates of the Caribbean: At World's End
# 14    280000000                      Avengers: Age of Ultron
# 1015  260000000                                  John Carter
# 380   260000000                                      Tangled
# 1677  258000000                                 Spider-Man 3
# 1246  255000000                              The Lone Ranger
# 123   250000000    The Hobbit: The Battle of the Five Armies
# 1187  250000000          The Hobbit: The Desolation of Smaug

# %%
# or 
#answer_1=data.sort_values(by=['budget'],ascending=False).head(3)
#answer_1

# %%
# тут вводим ваш ответ и добавлем в его список ответов (сейчас для примера стоит "1")
answer_ls.append(4)

# %% [markdown]
# # 2. Какой из фильмов самый длительный (в минутах)
# 1. The Lord of the Rings: The Return of the King	(tt0167260)
# 2. Gods and Generals	(tt0279111)
# 3. King Kong	(tt0360717)
# 4. Pearl Harbor	(tt0213149)
# 5. Alexander	(tt0346491)

# %%
data.sort_values(by = ['runtime'],ascending=False).head(3)
# Out:
#         imdb_id  popularity    budget     revenue  \
# 1158  tt0279111    0.469518  56000000    12923936
# 1082  tt0167260    7.122455  94000000  1118888979
# 1737  tt0462322    0.906938  67000000    25037897
#
#                                      original_title  \
# 1158                              Gods and Generals
# 1082  The Lord of the Rings: The Return of the King
# 1737                                     Grindhouse
#
#                                                    cast  \
# 1158  Stephen Lang|Jeff Daniels|Robert Duvall|Kevin ...
# 1082  Elijah Wood|Ian McKellen|Viggo Mortensen|Liv T...
# 1737  Kurt Russell|ZoÃ« Bell|Rosario Dawson|Vanessa ...
#
#                                                director  \
# 1158                                  Ronald F. Maxwell
# 1082                                      Peter Jackson
# 1737  Robert Rodriguez|Eli Roth|Quentin Tarantino|Ed...
#
#                                         tagline  \
# ...

# %%
answer_ls.append(2)

# %% [markdown]
# # 3. Какой из фильмов самый короткий (в минутах)
# Варианты ответов:
#
# 1. Home on the Range	tt0299172
# 2. The Jungle Book 2	tt0283426
# 3. Winnie the Pooh	tt1449283
# 4. Corpse Bride	tt0121164
# 5. Hoodwinked!	tt0443536

# %%
df3 = data.sort_values('runtime').head(1).loc[:,['runtime','original_title']]
df3
# Out:
#      runtime   original_title
# 769       63  Winnie the Pooh

# %%
#data.query('original_title in ["Home on the Range","The Jungle Book 2","Winnie the Pooh","Corpse Bride","Hoodwinked!"]')

# %%
answer_ls.append(3)

# %% [markdown]
# # 4. Средняя длительность фильма?
#
# Варианты ответов:
# 1. 115
# 2. 110
# 3. 105
# 4. 120
# 5. 100

# %%
data['runtime'].describe()
# Out:
# count    1890.000000
# mean      109.653439
# std        18.013641
# min        63.000000
# 25%        97.000000
# 50%       106.500000
# 75%       120.000000
# max       214.000000
# Name: runtime, dtype: float64

# %%
answer_ls.append(2)

# %% [markdown]
# # 5. Средняя длительность фильма по медиане?
# Варианты ответов:
# 1. 106
# 2. 112
# 3. 101
# 4. 120
# 5. 115

# %%
data.runtime.median()
# Out:
# 106.5

# %%
# прописать простую последовательность и подсчитать среднее через дескрайб, чтобы понять, он считает арифм ср или медиану
a = pd.Series([1,2,4,5,13],name = 'Zahlen')
a.describe()
# Out:
# count     5.000000
# mean      5.000000
# std       4.743416
# min       1.000000
# 25%       2.000000
# 50%       4.000000
# 75%       5.000000
# max      13.000000
# Name: Zahlen, dtype: float64

# %%
answer_ls.append(1)

# %% [markdown]
# # 6. Какой самый прибыльный фильм?
# Варианты ответов:
# 1. The Avengers	tt0848228
# 2. Minions	tt2293640
# 3. Star Wars: The Force Awakens	tt2488496
# 4. Furious 7	tt2820852
# 5. Avatar	tt0499549

# %%
#data.loc[:,['revenue','original_title']].sort_values(by=['revenue'],ascending=False)
df6 = data.loc[:,['original_title','profit']].copy()
df6.sort_values(by = 'profit',ascending = False).reset_index(drop=True)
# Out:
#                     original_title      profit
# 0                           Avatar  2544505847
# 1     Star Wars: The Force Awakens  1868178225
# 2                   Jurassic World  1363528810
# 3                        Furious 7  1316249360
# 4                     The Avengers  1299557910
# ...                            ...         ...
# 1885  The Adventures of Pluto Nash   -92896027
# 1886               Mars Needs Moms  -111007242
# 1887                     The Alamo  -119180039
# 1888               The Lone Ranger  -165710090
# 1889             The Warrior's Way  -413912431
#
# [1890 rows x 2 columns]

# %%
answer_ls.append(5)

# %% [markdown]
# # 7. Какой фильм самый убыточный?
# Варианты ответов:
# 1. Supernova tt0134983
# 2. The Warrior's Way tt1032751
# 3. Flushed Away	tt0424095
# 4. The Adventures of Pluto Nash	tt0180052
# 5. The Lone Ranger	tt1210819

# %%
data['profit'] = data.revenue-data.budget
new_data = data.loc[data['imdb_id'].isin(['tt0134983','tt1032751','tt0424095','tt0180052','tt1210819'])].loc[:,
                                                                                                           ['original_title',
                                                                                                           'profit']]
new_data.sort_values(by = ['profit'])
# Out:
#                     original_title     profit
# 491              The Warrior's Way -413912431
# 1246               The Lone Ranger -165710090
# 959   The Adventures of Pluto Nash  -92896027
# 1465                  Flushed Away  -84540684
# 1873                     Supernova  -75171919

# %%
df7 = data.loc[:,['profit','original_title','imdb_id']].copy()
df7.sort_values(by = 'profit')
liste7 = ['tt0134983','tt1032751','tt0424095','tt0180052','tt1210819']
worterbuch7 = {}
for i in liste7:
    df=df7[df7.imdb_id.str.contains(i,na=False)]
    worterbuch7[i] = df.iat[0,0]
min(worterbuch7,key = worterbuch7.get)
# Out:
# 'tt1032751'

# %%
df7 = data.loc[:,['profit','original_title']].copy()
df7.sort_values(by = 'profit')
liste7 = ["Supernova","The Warrior's Way","Flushed Away","The Adventures of Pluto Nash","The Lone Ranger"] 
worterbuch7 = {}
for i in liste7:
    df=df7[df7.original_title.str.contains(i,na=False)]
    worterbuch7[i] = df.iat[0,0]
min(worterbuch7,key = worterbuch7.get)
# Out:
# "The Warrior's Way"

# %%
answer_ls.append(2)

# %% [markdown]
# # 8. Сколько всего фильмов в прибыли?
# Варианты ответов:
# 1. 1478
# 2. 1520
# 3. 1241
# 4. 1135
# 5. 1398

# %%
data_8 = data.loc[:,['budget','revenue']]
data_8['profit'] = data.revenue-data.budget
len(data_8.query('profit>20').sort_values(by = 'profit',ascending=False))
# Out:
# 1478

# %%
answer_ls.append(1)

# %% [markdown]
# # 9. Самый прибыльный фильм в 2008 году?
# Варианты ответов:
# 1. Madagascar: Escape 2 Africa	tt0479952
# 2. Iron Man	tt0371746
# 3. Kung Fu Panda	tt0441773
# 4. The Dark Knight	tt0468569
# 5. Mamma Mia!	tt0795421

# %%
data_9 = data.loc[:,['revenue','budget','release_date','original_title']]
data_9['profit'] = data.revenue-data.budget
data_9_2008 = data_9[data_9.release_date.str.contains('2008',na = False)]
data_9_2008 = data_9_2008.sort_values(by = ['profit'],ascending = False)
df9=data_9_2008.iloc[:,3:].reset_index(drop = True)
df9
# Out:
#                                         original_title     profit
# 0                                      The Dark Knight  816921825
# 1    Indiana Jones and the Kingdom of the Crystal S...  601636033
# 2                                           Mamma Mia!  557841637
# 3                                        Kung Fu Panda  501744560
# 4                                              Hancock  474029371
# 5                          Madagascar: Escape 2 Africa  453900354
# 6                                             Iron Man  445174222
# 7                                    Quantum of Solace  386090727
# 8                                  Slumdog Millionaire  362910544
# 9                                             Twilight  355616625
# 10                                    Sex and the City  350252786
# 11                                             WALLÂ·E  341311860
# 12               The Mummy: Tomb of the Dragon Emperor  256128639
# ...

# %%
answer_ls.append(4)

# %% [markdown]
# # 10. Самый убыточный фильм за период с 2012 по 2014 (включительно)?
# Варианты ответов:
# 1. Winter's Tale	tt1837709
# 2. Stolen	tt1656186
# 3. Broken City	tt1235522
# 4. Upside Down	tt1374992
# 5. The Lone Ranger	tt1210819

# %%
data_10 = data.loc[:,['budget','revenue','original_title','release_date']]
data_10['profit'] = data_10.revenue-data_10.budget
# by - means: by years ( or filtered by years)
data_10_by = data_10[data_10.release_date.str.contains('2012|2013|2014',na=False)]
df10 = data_10_by.sort_values(by = 'profit').iloc[:,[2,4]].reset_index(drop=True)
df10
# Out:
#                                         original_title      profit
# 0                                      The Lone Ranger  -165710090
# 1                                             R.I.P.D.   -68351500
# 2                                          Upside Down   -51893525
# 3                      Legends of Oz: Dorothy's Return   -51337973
# 4                                   Bullet to the Head   -45510171
# 5                                          Broken City   -36298836
# 6                                               Stolen   -32893443
# 7                                        The Interview   -32694825
# 8                                        Winter's Tale   -29199769
# 9                         Sin City: A Dame to Kill For   -25592384
# 10                                              Oldboy   -25138978
# 11                                            47 Ronin   -24037525
# 12                                          Blood Ties   -23084528
# ...

# %%
answer_ls.append(5)

# %% [markdown]
# # 11. Какого жанра фильмов больше всего?
# Варианты ответов:
# 1. Action
# 2. Adventure
# 3. Drama
# 4. Comedy
# 5. Thriller

# %%
data.genres
# Out:
# 0       Action|Adventure|Science Fiction|Thriller
# 1       Action|Adventure|Science Fiction|Thriller
# 2              Adventure|Science Fiction|Thriller
# 3        Action|Adventure|Science Fiction|Fantasy
# 4                           Action|Crime|Thriller
#                           ...
# 1885             Adventure|Action|Science Fiction
# 1886                        Horror|Family|Foreign
# 1887     Adventure|Animation|Action|Comedy|Family
# 1888                                 Comedy|Drama
# 1889                                     Thriller
# Name: genres, Length: 1890, dtype: object

# %%
df11 = pd.DataFrame(data.genres.str.split('|').tolist()).stack().reset_index()
df11 = pd.DataFrame(df11[0])
df11.columns = ['genres']
df11 = df11.genres.value_counts().reset_index()
df11.columns = ['genre','frequency']
df11
# Out:
#               genre  frequency
# 0             Drama        782
# 1            Comedy        683
# 2          Thriller        597
# 3            Action        583
# 4         Adventure        416
# 5             Crime        315
# 6           Romance        308
# 7            Family        260
# 8   Science Fiction        248
# 9           Fantasy        223
# 10           Horror        176
# 11          Mystery        168
# 12        Animation        139
# 13            Music         64
# 14          History         62
# 15              War         58
# 16          Western         20
# 17      Documentary          8
# 18          Foreign          2

# %%
answer_ls.append(3)

# %% [markdown]
# # 12. Какого жанра среди прибыльных фильмов больше всего?
# Варианты ответов:
# 1. Drama
# 2. Comedy
# 3. Action
# 4. Thriller
# 5. Adventure

# %%
#df12_exp = data.copy()
#df12_exp['profit'] = df12_exp['revenue']-df12_exp['budget']
#df12_exp = df12_exp[['profit','genres']].copy()
#df12_exp = df12_exp.query('profit>0')
#profitable genres
#prof_gen = pd.DataFrame(df12_exp['genres'].str.split('|').tolist(),index=df12_exp['profit']).stack().reset_index([0])
#prof_gen.columns = ['profit','genres']
#prof_gen = prof_gen.pivot_table(index = 'genres',values = 'profit', aggfunc = sum)
#prof_gen.sort_values(by = ['profit'],ascending = False).reset_index()

#adventure - самый прибльный жанр

# %%
df12 = data.loc[:,['genres','profit']].copy()
df12 = pd.DataFrame(df12['genres'].str.split('|').tolist(),index = df12['profit']).stack().reset_index([0])
df12.rename(columns = {0:'genres'},inplace = True)
df12 = df12.query('profit>0')
df12 = df12.groupby('genres').count().reset_index()
df12.columns = ['genres','let`s count']
df12.sort_values(by = 'let`s count',ascending=False).reset_index(drop = True)

# ANSWER - 1 самый часто встречающийся жанр, среди прибыльных
# Out:
#              genres  let`s count
# 0             Drama          560
# 1            Comedy          551
# 2          Thriller          446
# 3            Action          444
# 4         Adventure          337
# 5           Romance          242
# 6             Crime          231
# 7            Family          226
# 8   Science Fiction          195
# 9           Fantasy          188
# 10           Horror          150
# 11        Animation          120
# 12          Mystery          119
# 13            Music           47
# 14          History           46
# 15              War           41
# 16          Western           12
# 17      Documentary            7

# %%
answer_ls.append(1)

# %% [markdown]
# # 13. Кто из режиссеров снял больше всего фильмов?
# Варианты ответов:
# 1. Steven Spielberg
# 2. Ridley Scott
# 3. Steven Soderbergh
# 4. Christopher Nolan
# 5. Clint Eastwood

# %%
df13 = data.director.reset_index([0]).iloc[:,[1]].copy()
df13 = pd.DataFrame(df13['director'].str.split('|').tolist()).stack().reset_index([0])
df13.columns = ['shit','director']
df13.iloc[:,[1]].reset_index().iloc[:,[1]].director.value_counts().head(5)
# Out:
# Steven Soderbergh    13
# Ridley Scott         12
# Clint Eastwood       12
# Robert Rodriguez     11
# Shawn Levy           10
# Name: director, dtype: int64

# %%
data.director.value_counts().head(10)
# Out:
# Steven Soderbergh                13
# Clint Eastwood                   12
# Ridley Scott                     12
# Steven Spielberg                 10
# Shawn Levy                       10
# M. Night Shyamalan                8
# Gore Verbinski                    8
# Adam Shankman                     8
# Bobby Farrelly|Peter Farrelly     8
# Ron Howard                        8
# Name: director, dtype: int64

# %%
answer_ls.append(3)

# %% [markdown]
# # 14. Кто из режиссеров снял больше всего Прибыльных фильмов?
# Варианты ответов:
# 1. Steven Soderbergh
# 2. Clint Eastwood
# 3. Steven Spielberg
# 4. Ridley Scott
# 5. Christopher Nolan

# %%
df14 = data.copy()
df14 = df14.loc[:,['director','budget','revenue']]
df14['profit'] = df14['revenue']-df14['budget']
df14 = df14.query('profit>0')
df14 = pd.DataFrame(df14[['director','profit']])
df14.director.value_counts()
# Out:
# Ridley Scott             12
# Clint Eastwood           10
# Steven Soderbergh        10
# Steven Spielberg         10
# Shawn Levy                9
#                          ..
# Terrence Malick           1
# Tom Vaughan               1
# Kirsten Sheridan          1
# Scott Moore|Jon Lucas     1
# Jeff Nichols              1
# Name: director, Length: 774, dtype: int64

# %%
answer_ls.append(4)

# %% [markdown]
# # 15. Кто из режиссеров принес больше всего прибыли?
# Варианты ответов:
# 1. Steven Spielberg
# 2. Christopher Nolan
# 3. David Yates
# 4. James Cameron
# 5. Peter Jackson

# %%
data['profit'] = data['revenue']-data['budget']
df15 = data.loc[:,['profit','director']].copy()
# расчленим режиссеров
df15 = pd.DataFrame(df15['director'].str.split('|').tolist(),index = df15['profit']).stack().reset_index([0])
df15.columns = ['profit','director']
df15.reset_index(drop = True)
# сгруппируем эти туши и профильтруем
df15 = df15.groupby(['director']).sum().reset_index().sort_values(by = ['profit'],ascending=False).reset_index(drop=True)
df15_stars_directors = df15.query('profit>0')
df15_stars_directors.head(6)
# Питер, а вы молодец!)
# Out:
#             director      profit
# 0      Peter Jackson  5202593685
# 1        David Yates  3379295625
# 2  Christopher Nolan  3162548502
# 3        J.J. Abrams  2839169916
# 4        Michael Bay  2760938960
# 5      James Cameron  2548546718

# %%
answer_ls.append(5)

# %% [markdown]
# # 16. Какой актер принес больше всего прибыли?
# Варианты ответов:
# 1. Emma Watson
# 2. Johnny Depp
# 3. Michelle Rodriguez
# 4. Orlando Bloom
# 5. Rupert Grint

# %%
data['profit'] = data['revenue']-data['budget']
stars = data[['cast','profit']].copy()
stars
stars_full = pd.DataFrame(stars['cast'].str.split('|').tolist(), index = stars['profit']).stack().reset_index([0])
stars_full.columns = ['profit', 'actor']
actors_top20 = (stars_full.pivot_table(index = 'actor', values = 'profit', aggfunc = 'sum')
                .sort_values(by = 'profit', ascending = False)
                .head(20)
                .reset_index())
actors_top20
# Out:
#                  actor      profit
# 0          Emma Watson  6666245597
# 1     Daniel Radcliffe  6514990281
# 2         Rupert Grint  6408638290
# 3         Ian McKellen  6087375777
# 4    Robert Downey Jr.  5316030161
# 5        Orlando Bloom  5148578162
# 6          Johnny Depp  4776417000
# 7        Ralph Fiennes  4739260140
# 8   Michelle Rodriguez  4608031235
# 9        Anne Hathaway  4490351538
# 10  Scarlett Johansson  4203244858
# 11         Ben Stiller  4201954571
# 12        Cameron Diaz  4146490085
# 13   Samuel L. Jackson  4036974161
# 14          Vin Diesel  3923216862
# 15      Dwayne Johnson  3899824603
# 16          Tom Cruise  3872196893
# 17         Chris Evans  3793939244
# 18         Gary Oldman  3708823251
# 19         Zoe Saldana  3572392568

# %%
df16 = data.loc[:,['cast','budget','revenue']]
df16['profit'] = df16['revenue']-df16['budget']
df16 = df16.query('profit>0').sort_values(by = ['profit'],ascending = False)

actors = ['Johnny Depp','Emma Watson','Orlando Bloom','Michelle Rodriguez','Rupert Grint']
dictor = {}
for i in actors:
    df = df16[df16.cast.str.contains(i,na = False)]
    dictor[i] = df.profit.sum()

max(dictor,key = dictor.get)
# Out:
# 'Emma Watson'

# %%
answer_ls.append(1)
#1

# %% [markdown]
# # 17. Какой актер принес меньше всего прибыли в 2012 году?
# Варианты ответов:
# 1. Nicolas Cage
# 2. Danny Huston
# 3. Kirsten Dunst
# 4. Jim Sturgess
# 5. Sami Gayle

# %%
df17 = data.copy()
df17['profit'] = df17.revenue-df17.budget
df17 = df17.loc[:,['cast','profit','release_date']].query("profit>0")
df17 = df17[df17['release_date'].str.contains('2012',na = False)]
df17 = pd.DataFrame(df17['cast'].str.split('|').tolist(),
                  index = df17['profit']).stack().reset_index([0])
df17.columns = ['profit','actors']
df17 = df17.pivot_table(index = 'actors',values = 'profit',aggfunc = sum).sort_values(by = ['profit']).reset_index().head(5)
df17
# Out:
#                  actors   profit
# 0  Aaron Taylor-Johnson  2000000
# 1          Blake Lively  2000000
# 2      Benicio del Toro  2000000
# 3     Jean-Luc Bilodeau  3493728
# 4             Matt Bush  3493728

# %%
df17 = data.loc[:,['cast','revenue','budget','release_date']]
df17 = df17[df17['release_date'].str.contains('2012',na = False)]
df17['profit'] = df17['revenue']-df17['budget']

df17 = df17.loc[:,['cast','profit']].query('profit>0').reset_index(drop = True)
df17 = pd.DataFrame(df17['cast'].str.split('|').tolist(),index = df17['profit']).stack().reset_index([0])
df17.columns = ['profit','actors']
df17 = df17.pivot_table(index = 'actors',values = 'profit',aggfunc = sum).sort_values(by = ['profit']).reset_index()
df17.head(5)
# Out:
#                  actors   profit
# 0  Aaron Taylor-Johnson  2000000
# 1          Blake Lively  2000000
# 2      Benicio del Toro  2000000
# 3     Jean-Luc Bilodeau  3493728
# 4             Matt Bush  3493728

# %%
df17 = data.loc[:,['cast','profit','release_date']]
df17 = df17[df17['release_date'].str.contains('2012',na = False)]
df17 = df17.loc[:,['cast','profit']]

actors = ['Nicolas Cage','Danny Huston','Kirsten Dunst','Jim Sturgess','Sami Gayle']
dictor = {}
for i in actors:
    df_i = df17[df17['cast'].str.contains(i,na = False)]
    dictor[i] = df_i['profit'].sum()

min(dictor,key = dictor.get)
# Out:
# 'Kirsten Dunst'

# %%
answer_ls.append(3)
# если вставить .query('profit>0').reset_index(drop=True) и отфильтровать только по прибыльным, то ответ будет 'Nicolas Cage'

# %% [markdown]
# # 18. Какой актер снялся в большем количестве высокобюджетных фильмов? (в фильмах где бюджет выше среднего по данной выборке)
# Варианты ответов:
# 1. Tom Cruise
# 2. Mark Wahlberg
# 3. Matt Damon
# 4. Angelina Jolie
# 5. Adam Sandler

# %%
df18 = data[data.budget > data.budget.mean()]
df18 = df18.loc[:,['cast','budget']]
actors = ['Tom Cruise','Mark Wahlberg','Matt Damon','Angelina Jolie','Adam Sandler']
dictor = {}
for i in actors:
    df = df18[df18['cast'].str.contains(i,na = False)]
    dictor[i] = len(df)
dictor
# Out:
# {'Tom Cruise': 15,
#  'Mark Wahlberg': 14,
#  'Matt Damon': 18,
#  'Angelina Jolie': 16,
#  'Adam Sandler': 17}

# %%
df18=data.copy()
df18=df18.loc[:,['cast','budget']]
df18=pd.DataFrame(df18['cast'].str.split('|').tolist(),
                  index=data['budget']).stack().reset_index([0]).query('budget>budget.mean()')

df18.columns=['films_in','actors']
df18['films_in']=1
df18=df18.pivot_table(index='actors',values='films_in',aggfunc=sum).reset_index()
df18=df18.sort_values(by=['films_in'],ascending=False).reset_index()
df18=df18.loc[:,['actors','films_in']]
df18
# Out:
#                        actors  films_in
# 0                  Matt Damon        18
# 1                Adam Sandler        17
# 2              Angelina Jolie        16
# 3           Samuel L. Jackson        15
# 4                  Tom Cruise        15
# ...                       ...       ...
# 1503          Jennifer Hudson         1
# 1504     Jennifer Jason Leigh         1
# 1505        Jennifer Saunders         1
# 1506           Jennifer Tilly         1
# 1507  Ã“lafur Darri Ã“lafsson         1
#
# [1508 rows x 2 columns]

# %%
answer_ls.append(3)

# %% [markdown]
# # 19. В фильмах какого жанра больше всего снимался Nicolas Cage?
# Варианты ответа:
# 1. Drama
# 2. Action
# 3. Thriller
# 4. Adventure
# 5. Crime

# %%
df19 = data.loc[:,['cast','genres']]
df19 = df19[df19['cast'].str.contains('Nicolas Cage',na = False)]
genres = ['Drama','Action','Thriller','Adventure','Crime']
dictor = {}
for i in genres:
    df = df19[df19['genres'].str.contains(i,na = False)]
    dictor[i] = len(df)
dictor
# Out:
# {'Drama': 12, 'Action': 17, 'Thriller': 15, 'Adventure': 7, 'Crime': 10}

# %%
df19 = data.copy()
df19 = df19.loc[:,['cast','genres']]
df19 = df19[df19['cast'].str.contains('Nicolas Cage',na = False)]
df19['cast'] = 'Nicolas Cage'
df19.columns = ['Nicolaj Kletka','genres']
df19 = pd.DataFrame(df19['genres'].str.split('|').tolist(),index = df19['Nicolaj Kletka']).stack().reset_index([0])
df19['Nicolaj Kletka'] = 1
df19.columns = ['counter','genres']
df_NC = df19.pivot_table(index = 'genres',values = 'counter',aggfunc = sum).sort_values(by = ['counter'],ascending = False)
df_NC.reset_index()
# Out:
#              genres  counter
# 0            Action       17
# 1          Thriller       15
# 2             Drama       12
# 3             Crime       10
# 4           Fantasy        8
# 5         Adventure        7
# 6            Comedy        6
# 7   Science Fiction        4
# 8         Animation        3
# 9            Family        3
# 10          Mystery        3
# 11          History        2
# 12           Horror        1
# 13          Romance        1
# 14              War        1

# %%
answer_ls.append(2)

# %% [markdown]
# # 20. Какая студия сняла больше всего фильмов?
# Варианты ответа:
# 1. Universal Pictures (Universal)
# 2. Paramount Pictures
# 3. Columbia Pictures
# 4. Warner Bros
# 5. Twentieth Century Fox Film Corporation

# %%
df20 = data.loc[:,['production_companies']].copy()
df20 = pd.DataFrame(df20['production_companies'].str.split("|").tolist()).stack().reset_index(drop=True)
df20 = df20.value_counts().reset_index().sort_values(by = ['index'],ascending = False)
pd.set_option('display.max_row',1000)
df20.columns = ['production','count']
df20.head(3)
#df20=df20.pivot_table(index='production',values='count',
#                     aggfunc=sum).sort_values(by=['count'],ascending=False).reset_index()
#df20.head(60)
#df20=pd.DataFrame(df20['production']).reset_index()
#df20=df20.loc[:,['production']]
#df20.describe()
# Out:
#                      production  count
# 1647                      uFilm      1
# 599            platinum studios      2
# 990   Zucker/Netter Productions      1

# %%
df220 = data.loc[:,['production_companies']].copy()
compashki = ['Universal','Paramount Pictures','Columbia Pictures','Warner Bros.','Twentieth Century Fox Film Corporation']
worterbuch = {}

for i in compashki:
    df = df220[df220['production_companies'].str.contains(i,na = False)]
    worterbuch[i] = len(df)
#max(worterbuch,key=worterbuch.get)
worterbuch
# Out:
# {'Universal': 185,
#  'Paramount Pictures': 122,
#  'Columbia Pictures': 163,
#  'Warner Bros.': 183,
#  'Twentieth Century Fox Film Corporation': 109}

# %%
answer_ls.append(1)

# %% [markdown]
# # 21. Какая студия сняла больше всего фильмов в 2015 году?
# Варианты ответа:
# 1. Universal Pictures
# 2. Paramount Pictures
# 3. Columbia Pictures
# 4. Warner Bros
# 5. Twentieth Century Fox Film Corporation

# %%
# отфильтровать, (студия, год) , сгруппировать , пересчиатть 
#1
df21 = data.loc[:,['production_companies','release_year']].query('release_year==2015').copy()
df21 = pd.DataFrame(df21['production_companies'].str.split('|').tolist()).stack().reset_index([0])
df21.rename(columns = {0: 'production'}, inplace = True)
df21 = pd.DataFrame(df21['production']).reset_index(drop = True)
df21 = df21[df21.production.str.contains('Universal|Paramount Pictures|Columbia Pictures|Warner Bros|Twentieth Century Fox Film Corporation',
                                      na = False)].reset_index()
df21['index'] = 1
#2
df21.rename(columns = {'index':'count'},inplace = True)
df21 = df21.groupby('production').sum().reset_index().sort_values(by = 'count',ascending = False).reset_index(drop = True)
df21
#answer - 4
# Out:
#                                production  count
# 0                            Warner Bros.     12
# 1                      Universal Pictures     10
# 2  Twentieth Century Fox Film Corporation      8
# 3                       Columbia Pictures      7
# 4                      Paramount Pictures      7
# 5  Universal Pictures International (UPI)      1
# 6                       Universal Studios      1

# %%
answer_ls.append(4)

# %% [markdown]
# # 22. Какая студия заработала больше всего денег в жанре комедий за все время?
# Варианты ответа:
# 1. Warner Bros
# 2. Universal Pictures (Universal)
# 3. Columbia Pictures
# 4. Paramount Pictures
# 5. Walt Disney

# %%
#1. Необходимо создать новую колонку данных и копию датафрейма с требуемыми колонками для дальнейшей работы
data['profit'] = data.revenue-data.budget
df22 = data.loc[:,['profit','production_companies','genres']].copy()
#2. Выбираем только требуемый жанр
df22 = df22[df22.genres.str.contains('Comedy',na  =False)]
#3. Расчленяем компании в отдельные строки
df22 = pd.DataFrame(df22['production_companies'].str.split('|').tolist(),index = df22['profit']).stack().reset_index([0])
df22.rename(columns = {0:'production'},inplace = True)
df22 = df22.reset_index(drop=True)
#4. Осуществляем монгольскую хитрость, выбираем только те строки, где есть необходимые компании
df22 = df22[df22.production.str.contains('Warner Bros|Universal|Columbia Pictures|Paramount Pictures|Walt Disney',na = False)]

#5. Фильтруем дочек компании Universal
def filter_universal(x):
    if 'Universal' in x:
        x = 'Universal'
        return x
    return x

df22['production'] = df22['production'].apply(filter_universal)
df22

#6. Получаем ответ
df22 = df22.groupby('production').sum().sort_values(by = 'profit',ascending = False).reset_index()
df22


# answer - 2




# Здесь покоится гениальный код......
#pd.set_option('display.max_row',100)
#df22.head(20)
#worterbuch={}
#liste=['Warner Bros','Universal','Columbia Pictures','Paramount Pictures','Walt Disney']
#for i in liste:
#    df=df22[df22.production.str.contains(i,na=False)]
#    sumishe=df['profit'].sum()
#    worterbuch[i]=sumishe

#max(worterbuch,key=worterbuch.get)

#worterbuch
# Out:
#                                 production      profit
# 0                                Universal  9150183849
# 1                     Walt Disney Pictures  7669710326
# 2                        Columbia Pictures  5646343696
# 3                             Warner Bros.  3894922770
# 4                       Paramount Pictures  3055625722
# 5            Columbia Pictures Corporation  1817280373
# 6            Walt Disney Animation Studios  1142430016
# 7      Walt Disney Studios Motion Pictures   678708609
# 8                   Warner Bros. Animation   463037717
# 9            Walt Disney Feature Animation   227711813
# 10  Warner Bros. Interactive Entertainment    -2514873
# 11                   Warner Bros. Pictures   -54738687

# %%
answer_ls.append(2)

# %%
#data['director'].value_counts().to_frame()

# %% [markdown]
# # 23. Какая студия заработала больше всего денег в 2012 году?
# Варианты ответа:
# 1. Universal Pictures (Universal)
# 2. Warner Bros
# 3. Columbia Pictures
# 4. Paramount Pictures
# 5. Lucasfilm

# %%
#sort by studio, year, profit. aggregate studios and summ profit
data['profit'] = data.revenue-data.budget
df23 = data.loc[:,['production_companies','release_year','profit']].copy()
df23 = df23.query('release_year==2012')
df23 = pd.DataFrame(df23['production_companies'].str.split('|').tolist(),index = df23['profit']).stack().reset_index([0])
df23.rename(columns = {0:'production'},inplace = True)
df23 = df23.groupby('production').sum().sort_values(by = 'profit',ascending=False).reset_index()
df23 = df23[df23.production.str.contains('Universal|Warner Bros|Columbia Pictures|Paramount Pictures|Lucasfilm',
                                       na = False)].reset_index(drop=True)
df23
# answer - 3
# Out:
#            production      profit
# 0   Columbia Pictures  2501406608
# 1  Universal Pictures  1981011579
# 2        Warner Bros.  1258020056
# 3  Paramount Pictures   410726715
# 4      Lucasfilm Ltd.    -7634623

# %%
answer_ls.append(3)

# %% [markdown]
# # 24. Самый убыточный фильм от Paramount Pictures
# Варианты ответа:
#
# 1. K-19: The Widowmaker tt0267626
# 2. Next tt0435705
# 3. Twisted tt0315297
# 4. The Love Guru tt0811138
# 5. The Fighter tt0964517

# %%
# фильтр. взять профит, продакшн, название
# выбрать только парамаунт и составить датафрейм с значениями отсортированными
df24 = data.loc[:,['budget','revenue','production_companies','original_title']].copy()
df24['profit'] = df24.revenue-df24.budget
df24 = df24.iloc[:,2:]
df24 = df24[df24['production_companies'].str.contains('Paramount Pictures',na = False)]

df24 = df24.iloc[:,1:].sort_values(by = 'profit').reset_index(drop = True)
df24
#1
# Out:
#                                         original_title     profit
# 0                                 K-19: The Widowmaker  -64831034
# 1                                             Timeline  -60519261
# 2                                                 Next  -51788987
# 3                                                Alfie  -46604061
# 4                                              Twisted  -24805000
# 5                                 Domestic Disturbance  -20750706
# 6                                        The Love Guru  -20180936
# 7                                     A Thousand Words  -17955723
# 8                                          The Fighter  -15809131
# 9                                              Abandon  -14280643
# 10                                        Suspect Zero  -14000000
# 11                                        Serving Sara  -12069815
# 12               Sky Captain and the World of Tomorrow  -12041304
# ...

# %%
answer_ls.append(1)

# %%
#Создайте датафрейм, где будет 5 склеек, 5 разных компаний, их фильмы и доход
data['profit'] = data.revenue-data.budget
data.loc[:,['original_title','profit','production_companies']].sort_values(by = 'profit',ascending=False).reset_index(drop = True).head(5)
# Out:
#                  original_title      profit  \
# 0                        Avatar  2544505847
# 1  Star Wars: The Force Awakens  1868178225
# 2                Jurassic World  1363528810
# 3                     Furious 7  1316249360
# 4                  The Avengers  1299557910
#
#                                 production_companies
# 0  Ingenious Film Partners|Twentieth Century Fox ...
# 1          Lucasfilm|Truenorth Productions|Bad Robot
# 2  Universal Studios|Amblin Entertainment|Legenda...
# 3  Universal Pictures|Original Film|Media Rights ...
# 4                                     Marvel Studios

# %% [markdown]
# # 25. Какой Самый прибыльный год (заработали больше всего)?
# Варианты ответа:
# 1. 2014
# 2. 2008
# 3. 2012
# 4. 2002
# 5. 2015

# %%
#отфильтровать ( год, профит), составить группы и просуммировать
df25 = data.loc[:,['budget','revenue','release_year']].copy()
df25['profit'] = df25.revenue-df25.budget
df25 = df25.groupby('release_year').sum().sort_values(by = 'profit',ascending=False).reset_index().iloc[:,[0,3]]
df25
#5
# Out:
#     release_year       profit
# 0           2015  18668572378
# 1           2014  16397812953
# 2           2012  16077001687
# 3           2013  15243179791
# 4           2011  14730241341
# 5           2009  13423744372
# 6           2010  13117292530
# 7           2008  11663881990
# 8           2007  11565911801
# 9           2004   9634180720
# 10          2003   9228823312
# 11          2002   9002361487
# 12          2005   8981925558
# 13          2006   8691077320
# 14          2001   7950614865
# 15          2000   6101399805

# %%
answer_ls.append(5)

# %% [markdown]
# # 26. Какой Самый прибыльный год для студии Warner Bros?
# Варианты ответа:
# 1. 2014
# 2. 2008
# 3. 2012
# 4. 2010
# 5. 2015

# %%
df26 = data[data.production_companies.str.contains('Warner Bros',na = False)].copy()
df26 = df26.loc[:,['release_year','budget','revenue']]
df26['profit'] = df26.revenue-df26.budget
df26 = df26.groupby('release_year').sum().sort_values(by = ['profit'],ascending = False).reset_index().iloc[:,[0,3]]
df26
#1
# Out:
#     release_year      profit
# 0           2014  2295464519
# 1           2007  2201675217
# 2           2008  2134595031
# 3           2010  1974712985
# 4           2011  1871393682
# 5           2003  1855493377
# 6           2009  1822454136
# 7           2013  1636453400
# 8           2004  1631933725
# 9           2005  1551980298
# 10          2001  1343545668
# 11          2012  1258020056
# 12          2002  1022709901
# 13          2015   870368348
# 14          2006   620170743
# 15          2000   452631386

# %%
answer_ls.append(1)

# %% [markdown]
# # 27. В каком месяце за все годы суммарно вышло больше всего фильмов?
# Варианты ответа:
# 1. Январь
# 2. Июнь
# 3. Декабрь
# 4. Сентябрь
# 5. Май

# %%
#Идея: 1. Отсортировать по месяцам. 2.каждому фильму задать значение:1. 3.Сгруппировать и пересчитать
#1
df27 = data.loc[:,['release_date','original_title']].copy()
df27['release_date'] = df27['release_date'].str.slice(stop = 2)
df27['release_date'] = df27['release_date'].str.replace('/','')
#2
df27['original_title'] = 1
df27.columns = ['Month','Number of films in this month']
#3
df27 = df27.groupby('Month').sum().sort_values(by='Number of films in this month',ascending = False).reset_index()
df27 = df27.replace({'Month': {"1": 'Januar', "2": 'Februar', "3": 'March', "4": 'April'
                       , "5": 'May', "6": 'Juni', "7": 'Juli', "8": 'August'
                       , "9": 'September', "10": 'October', "11": 'November', "12": 'December'}})
df27
#Answer - 4 Сентябрь



#df27['release_date']=df27['release_date'].replace({'/':''}, regex=True)
#df.replace({'replace_date'='^ba.*'}, {'replace_date'='new'}, regex=True)
# Out:
#         Month  Number of films in this month
# 0   September                            227
# 1    December                            191
# 2     October                            186
# 3      August                            161
# 4       March                            156
# 5       April                            149
# 6        Juni                            147
# 7    November                            146
# 8        Juli                            142
# 9         May                            140
# 10    Februar                            135
# 11     Januar                            110

# %%
#df = pd.DataFrame({'A': ['bat', 'foo', 'bait'],
#                   'B': ['abc', 'bar', 'xyz']})
#df.replace(to_replace=r'^ba.$', value='new', regex=True)
#df.replace({'A': r'^ba.$'}, {'A': 'new'}, regex=True)
#df=df.A.replace(regex='^ba.*',value='new').reset_index()
#df

# %%
answer_ls.append(4)

# %% [markdown]
# # 28. Сколько суммарно вышло фильмов летом? (за июнь, июль, август)
# Варианты ответа:
# 1. 345
# 2. 450
# 3. 478
# 4. 523
# 5. 381

# %%
# sort by movies,months. aggregate by months and count total number for each of them

df28 = data.loc[:,['release_date','original_title']].copy()
df28['release_date'] = df28['release_date'].str.slice(stop = 2).str.replace('/','')
df28 = df28[df28['release_date'].str.contains('6|7|8',na = False)]
df28.rename(columns = {'release_date':'Month','original_title':'score'},inplace = True)
df28['score'] = 1
df28=df28.groupby('Month').sum().sort_values(by = 'score',ascending = False).reset_index()
df28.score.sum()
# answer - 2 
answer28 = pd.DataFrame([df28.score.sum()],columns = ['Summer'],index = ['Total Sum'])
answer28
# Out:
#            Summer
# Total Sum     450

# %%
answer_ls.append(2)

# %% [markdown]
# # 29. Какой режисер выпускает (суммарно по годам) больше всего фильмов зимой?
# Варианты ответов:
# 1. Steven Soderbergh
# 2. Christopher Nolan
# 3. Clint Eastwood
# 4. Ridley Scott
# 5. Peter Jackson

# %%
df29 = data.loc[:,['director','release_date']].copy()
df29['release_date'] = df29['release_date'].str.slice(stop = 2).str.replace('/','')

df29 = df29[df29.release_date.str.match('12|1$|2$',na = False)].reset_index()
df29.rename(columns = {'index':'score'},inplace = True)
df29['score'] = 1
df29=df29.iloc[:,0:2]

df29 = df29.groupby('director').sum().sort_values(by = 'score',ascending=False).reset_index()
df29.head(10)
df29[df29.director.str.contains('Steven Soderbergh|Christopher Nolan|Clint Eastwood|Ridley Scott|Peter Jackson',na = False)].reset_index(drop=True)
# answer - 5
# Out:
#             director  score
# 0      Peter Jackson      7
# 1  Steven Soderbergh      6
# 2     Clint Eastwood      6
# 3       Ridley Scott      3

# %%
answer_ls.append(5)

# %% [markdown]
# # 30. Какой месяц чаще всего по годам самый прибыльный?
# Варианты ответа:
# 1. Январь
# 2. Июнь
# 3. Декабрь
# 4. Сентябрь
# 5. Май

# %%
#мне нужно за каждый год подсчитать самый прибыльный месяц и отсортировать, какой чаще всего прибыльный
#1. Требуется отфильтровать датафрейм по датам и профиту. 
#2. подсчитать количество самых прибыльных месяцев за каждый год. Создать датафрейм, где будет вбиты года, 
# а потом отранжированны месяцы по профиту
#3. найти самый прибыльный месяц в каждом году и отсортировать, какой чаще встречается


df30 = data.loc[:,['release_date','profit']].copy()


liste = []
for i in range(2000,2016):
    df_year_sorted = df30[df30.loc[:,'release_date'].str.contains(str(i),na=False)]
    df_year_sorted.loc[:,'release_date'] = df_year_sorted.loc[:,'release_date'].str.slice(stop = 2).str.replace('/','')
    month_of_year = df_year_sorted.sort_values(by = ['profit'],ascending = False).reset_index(drop = True).iat[0,0]
    liste.append(month_of_year)

liste
Series_answer = pd.Series(liste)
answer = pd.DataFrame(data=Series_answer,columns = ['Month'])
answer['Month'].value_counts()
# asnwer - 3


df30

#def ripper(x):
#    df30=data.loc[:,['release_date','profit']].copy()
    # 1. filter year
    # 2. chop it
    # 3. choose the most profitable month
    # 4. add this number to a list
# Out:
#      release_date      profit
# 0        6/9/2015  1363528810
# 1       5/13/2015   228436354
# 2       3/18/2015   185238201
# 3      12/15/2015  1868178225
# 4        4/1/2015  1316249360
# ...           ...         ...
# 1885    7/13/2000    82299717
# 1886   10/27/2000    -8444012
# 1887    6/30/2000   -40865180
# 1888    2/16/2000    -3962091
# 1889    7/19/2000    -9782502
#
# [1890 rows x 2 columns]

# %%
df30 = data.loc[:,['release_date','profit']].copy()


df30.loc[:,'release_date'] = df30.loc[:,'release_date'].str.slice(stop = 2).str.replace('/','')
month_of_year = df30.sort_values(by = ['profit'],ascending = False).reset_index(drop = True)
month_of_year.groupby('release_date').sum().sort_values(by = 'profit',ascending=False).reset_index()
# asnwer - 2
# Out:
#    release_date       profit
# 0             6  27551262500
# 1            12  26563071474
# 2             5  25039516141
# 3            11  18654155473
# 4             7  18307895020
# 5             3  13720216540
# 6            10  12994907859
# 7             4  12876005537
# 8             9  10878921041
# 9             8   9640610446
# 10            2   8854574425
# 11            1   5396885454

# %%
#data['income']=data['revenue']-data['budget']
#data['month'] = pd.to_datetime(data.release_date, format='%m/%d/%Y').dt.month
#pd.pivot_table(data, values='income', index='month', columns='release_year', aggfunc='sum').idxmax()

# %%
answer_ls.append(2)

# %% [markdown]
# # 31. Названия фильмов какой студии в среднем самые длинные по количеству символов?
# Варианты ответа:
# 1. Universal Pictures (Universal)
# 2. Warner Bros
# 3. Jim Henson Company, The
# 4. Paramount Pictures
# 5. Four By Two Productions

# %% [markdown]
# ###  План действий
# 1. Отфильтровать датафрейм, выбрав столбцы : название фильма, студии
# 2. Разделить все названия продакшнов
# 3. видоизменить столбцы функциями , превратив названия фильмов в длину символов, а студии отсортировтаь по неоходимым названиям
# 4. сгруппировать и подсчитать для каждой среднюю длину по количеству символов

# %%
# 1 STEP
df31 = data.loc[:,['production_companies','original_title']].copy()
df31 = pd.DataFrame(df31['production_companies'].str.split("|").tolist(),index = df31['original_title']).stack().reset_index([0])
df31.rename(columns = {0:'production'},inplace = True)


# 1 метод
#df31=df31[df31['production'].str.contains('Universal|Paramount Pictures|Jim Henson Company|Four By Two Productions|Warner Bros.',na=False)]
#df31=df31.reset_index(drop=True)

# 2 метод
#liste31=['Universal Pictures','Paramount Pictures','Jim Henson Company','Four By Two Productions','Warner Bros.']
#df31=df31.query('production in @liste31')

# воспользуюсь первым методом, просто экспериментирую

# %%
# 2 STEP
df31 = df31[df31['production'].str.contains('Universal|Paramount Pictures|Jim Henson Company|Four By Two Productions|Warner Bros.',na=False)]
df31 = df31.reset_index(drop = True)

# %%
# 3 STEP
def len_of_name(stroka):
    zahl=len(stroka)
    return zahl
#zahl - число по немецки 

df31['original_title'] = df31['original_title'].apply(len_of_name)

df31.rename(columns = {'original_title':'filmname_lenth'},inplace = True)

def renamer(x):
    if 'Universal' in x:
        x = 'Universal'
        return x
    elif 'Paramount' in x:
        x = 'Paramount'
        return x
    elif 'Warner' in x:
        x = 'Warner Bros'
        return x
    else:
        return x
        
df31['production'] = df31['production'].apply(renamer)
df31


#pd.set_option("display.max_rows", 500)
# Out:
#      filmname_lenth   production
# 0                14    Universal
# 1                 9    Universal
# 2                18    Paramount
# 3                 7    Universal
# 4                17  Warner Bros
# ..              ...          ...
# 493              14  Warner Bros
# 494               6  Warner Bros
# 495              15  Warner Bros
# 496              36    Universal
# 497              12  Warner Bros
#
# [498 rows x 2 columns]

# %%
# 4 STEP

df31.groupby('production').mean().reset_index()

# answer - 5
# Out:
#                 production  filmname_lenth
# 0  Four By Two Productions       83.000000
# 1  Jim Henson Company, The       59.000000
# 2                Paramount       17.032787
# 3                Universal       14.775401
# 4              Warner Bros       15.283422

# %%
#Borat: Cultural Learnings of America for Make Benefit Glorious Nation of Kazakhstan

# %%
answer_ls.append(5)

# %% [markdown]
# # 32. Названия фильмов какой студии в среднем самые длинные по количеству слов?
# Варианты ответа:
# 1. Universal Pictures (Universal)
# 2. Warner Bros
# 3. Jim Henson Company, The
# 4. Paramount Pictures
# 5. Four By Two Productions

# %%
pd.Series(['foo!', 'fuz', np.nan]).str.replace('[!]', 'ba', regex = True)
# Out:
# 0    fooba
# 1      fuz
# 2      NaN
# dtype: object

# %%
#взять нужные данные из, фильтрануть. сгруппировать по компаниям и подсчитать по формуле среднюю длину названия фильма по словам

df32 = data.loc[:,["original_title",'production_companies']].copy()
df32 = pd.DataFrame(df32['production_companies'].str.split("|").tolist(),index = df32['original_title']).stack().reset_index([0])
df32.rename(columns={0:'production'},inplace=True)
#а теперь я отсортирую фрейм по нужным компаниям 1 методом  из задания 31.
df32 = df32[df32['production'].str.contains('Universal|Paramount Pictures|Jim Henson Company|Four By Two Productions|Warner Bros.',na=False)]
df32 = df32.reset_index(drop = True)
#воспользуемся функцией из предыдущего задания
df32['production']=df32['production'].apply(renamer)
df32['original_title']=df32['original_title'].str.replace("[^A-Za-z]"," ",regex = True).str.split().tolist()

def die_Lange(x):
    x = len(x)
    return x
df32['original_title']=df32['original_title'].apply(die_Lange)
df32.groupby('production').mean().reset_index()
# answer - 5
# Out:
#                 production  original_title
# 0  Four By Two Productions       12.000000
# 1  Jim Henson Company, The       10.000000
# 2                Paramount        2.803279
# 3                Universal        2.582888
# 4              Warner Bros        2.748663

# %%
answer_ls.append(5)

# %% [markdown]
# # 33. Сколько разных слов используется в названиях фильмов?(без учета регистра)
# Варианты ответа:
# 1. 6540
# 2. 1002
# 3. 2461
# 4. 28304
# 5. 3432

# %%
# взять названия фильмов, отфильтровать, чтобы были только слова, без знаков лишних, а дальше nunique()
df33 = data.loc[:,['original_title']].copy()

df33['original_title'] = df33['original_title'].str.replace('[^A-Za-z]'," ",regex=True)

allnames = list(df33['original_title'])
zeile = " "
#string по-немецки "die Zeile"
zeile = zeile.join(allnames)
zeile = zeile.split()

dfnames=pd.DataFrame(zeile,columns = ['Names'])
dfnames['Names'] = dfnames['Names'].str.lower()
dfnames['Names'].nunique()
# Out:
# 2296

# %%
#второй вариант фильтрации
#df33['original_title']=df33['original_title'].str.replace('[^A-Za-z]'," ",regex=True)
dfnames_ver2 = pd.DataFrame(df33['original_title'].str.split().tolist()).stack().reset_index([0])
dfnames_ver2 = dfnames_ver2.loc[:,[0]]
dfnames_ver2.rename(columns = {0:'Names'},inplace = True)
dfnames_ver2 = dfnames_ver2.reset_index(drop = True)
dfnames_ver2['Names'] = dfnames_ver2['Names'].str.lower()
pd.set_option("display.max_rows", 500)

dfnames_ver2.drop_duplicates(subset = 'Names',keep = 'first',inplace = True)
dfnames_ver2.count()
# Out:
# Names    2296
# dtype: int64

# %%
answer_ls.append(3)
# Я сделал даже лучше, чем предполагалось в ответе, так как я убрал лишние символы, 
# не являющимися словами и портящими статистику
# df33['original_title']=df33['original_title'].str.replace('[^A-Za-z]'," ",regex=True) вот это убрать и будет 2461

# %% [markdown]
# # 34. Какие фильмы входят в 1 процент лучших по рейтингу?
# Варианты ответа:
# 1. Inside Out, Gone Girl, 12 Years a Slave
# 2. BloodRayne, The Adventures of Rocky & Bullwinkle
# 3. The Lord of the Rings: The Return of the King
# 4. 300, Lucky Number Slevin

# %%
maxvote = data[['vote_average']].max()
floor = round(int(maxvote)-int(maxvote)/100,1)
data.query('vote_average>=@floor')

# answers- 1 ( also 3 is ok)
# Out:
#         imdb_id  popularity     budget     revenue  \
# 9     tt2096673    6.326804  175000000   853708609
# 34    tt3170832    3.557846    6000000    35401758
# 118   tt0816692   24.949134  165000000   621752480
# 119   tt2015381   14.311205  170000000   773312399
# 125   tt2084970    8.110711   14000000   233555708
# 128   tt2267998    6.438727   61000000   369330363
# 138   tt2278388    4.930820   30000000   174600318
# 370   tt1375666    9.363643  160000000   825500000
# 600   tt0468569    8.466668  185000000  1001921825
# 873   tt0253474    2.364204   35000000   120072577
# 1082  tt0167260    7.122455   94000000  1118888979
# 1184  tt0993846    4.877927  100000000   392000694
# 1192  tt2024544    3.625529   20000000   187000000
# 1801  tt0209144    3.095625    9000000    39723096
#
#                                      original_title  \
# 9                                        Inside Out
# 34                                             Room
# ...

# %%
answer_ls.append(1)

# %% [markdown]
# # 35. Какие актеры чаще всего снимаются в одном фильме вместе
# Варианты ответа:
# 1. Johnny Depp & Helena Bonham Carter
# 2. Hugh Jackman & Ian McKellen
# 3. Vin Diesel & Paul Walker
# 4. Adam Sandler & Kevin James
# 5. Daniel Radcliffe & Rupert Grint

# %%
df35=data.loc[:,['cast']].copy()
def checker(x):
    if "Johnny Depp" in x and "Helena Bonham Carter" in x:
        x='J and H'
        return x
    elif "Hugh Jackman" in x and "Ian McKellen" in x:
        x='H and I'
        return x
    elif "Vin Diesel" in x and "Paul Walker" in x:
        x= "V and P"
        return x
    elif "Adam Sandler" in x and "Kevin James" in x:
        x= "A and K"
        return x
    elif "Daniel Radcliffe" in x and "Rupert Grint" in x:
        x="D and R"
        return x


df35['cast']=df35['cast'].apply(checker)

df35=df35.dropna().sort_values(by='cast').reset_index(drop=True)

df35['cast'].value_counts()
#answer - 5
# Out:
# D and R    8
# J and H    6
# H and I    5
# A and K    5
# V and P    5
# Name: cast, dtype: int64

# %%
answer_ls.append(5)

# %% [markdown]
# # 36. У какого из режиссеров выше вероятность выпустить фильм в прибыли? (5 баллов)101
# Варианты ответа:
# 1. Quentin Tarantino
# 2. Steven Soderbergh
# 3. Robert Rodriguez
# 4. Christopher Nolan
# 5. Clint Eastwood

# %%
# фильтрануть режиссеров, пустить по формуле их
df36 = data.loc[:,['director']].copy()
df36['profit'] = data['revenue'] - data['budget']

df36 = pd.DataFrame(df36['director'].str.split('|').tolist(), index=df36['profit']).stack().reset_index([0])
df36.rename(columns={0:'director'},inplace=True)
df36=df36[df36['director'].str.contains('Quentin Tarantino|Steven Soderbergh|Robert Rodriguez|Christopher Nolan|Clint Eastwood',na=False)]
df36=df36.reset_index(drop=True)

liste36 = ['Quentin Tarantino','Steven Soderbergh','Robert Rodriguez','Christopher Nolan','Clint Eastwood']
worterbuch = {}
for i in liste36:
    df = df36.query('director in @i')
    prob = len(df.query('profit>0'))/len(df['profit'])
    worterbuch[i] = prob
worterbuch



# answer - 4
# Out:
# {'Quentin Tarantino': 0.8571428571428571,
#  'Steven Soderbergh': 0.7692307692307693,
#  'Robert Rodriguez': 0.7272727272727273,
#  'Christopher Nolan': 1.0,
#  'Clint Eastwood': 0.8333333333333334}

# %%
answer_ls.append(4)

# %% [markdown]
# # Submission

# %%
len(answer_ls)
# Out:
# 36

# %%
pd.DataFrame({'Id':range(1,len(answer_ls)+1), 'Answer':answer_ls}, columns=['Id', 'Answer'])
# Out:
#     Id  Answer
# 0    1       4
# 1    2       2
# 2    3       3
# 3    4       2
# 4    5       1
# 5    6       5
# 6    7       2
# 7    8       1
# 8    9       4
# 9   10       5
# 10  11       3
# 11  12       1
# 12  13       3
# 13  14       4
# 14  15       5
# 15  16       1
# 16  17       3
# 17  18       3
# 18  19       2
# 19  20       1
# 20  21       4
# 21  22       2
# 22  23       3
# 23  24       1
# 24  25       5
# 25  26       1
# 26  27       4
# 27  28       2
# 28  29       5
# 29  30       2
# 30  31       5
# 31  32       5
# 32  33       3
# 33  34       1
# 34  35       5
# 35  36       4

# %%
# дальше уже эксперименты пошли .... .неважно

# %%
# Out:
#   File "<ipython-input-119-f8e52d11c89d>", line 1
#     Id	Answer
#       	     ^
# SyntaxError: invalid syntax

# %%
import collections
# Создадим список, в который поместим всех режиссеров
director = []
for i in data['director']:
    for j in i.split('|'): 
        director.append(j)
# Методом .Counter() посчитаем количество режиссеров в director и группируем результаты
director_films_count = collections.Counter()
for i in director:
    director_films_count[i]+=1

director_films_count
# Чтобы не искать режиссера с наибольшим количеством фильмов, отсортируем словарь director_films_count
# Для этого создадим список кортежей ("ключ", "значение")
list_director_films_count = list(director_films_count.items())
# Отсортируем его по вторым элементам
list_director_films_count.sort(key=lambda i: i[1], reverse = True)
#Выведем результат на экран
for i in list_director_films_count:
    print(i[0], ':', i[1])
# Out:
# Steven Soderbergh : 13
# Ridley Scott : 12
# Clint Eastwood : 12
# Robert Rodriguez : 11
# Steven Spielberg : 10
# Shawn Levy : 10
# Peter Farrelly : 10
# Bobby Farrelly : 9
# Tim Burton : 9
# Antoine Fuqua : 8
# Ron Howard : 8
# M. Night Shyamalan : 8
# Christopher Nolan : 8
# Peter Jackson : 8
# Michael Bay : 8
# Brett Ratner : 8
# Todd Phillips : 8
# Adam Shankman : 8
# Gore Verbinski : 8
# Quentin Tarantino : 7
# Paul W.S. Anderson : 7
# Lasse HallstrÃ¶m : 7
# Dennis Dugan : 7
# Marc Forster : 7
# Francis Lawrence : 6
# Adam McKay : 6
# Robert Zemeckis : 6
# Andy Fickman : 6
# David Fincher : 6
# Tim Story : 6
# Zack Snyder : 6
# Robert Luketic : 6
# Steve Carr : 6
# Sam Raimi : 6
# Tony Scott : 6
# Joel Coen : 6
# Martin Scorsese : 6
# Danny Boyle : 6
# Louis Leterrier : 6
# Brian Robbins : 6
# Rob Cohen : 6
# Peter Berg : 6
# Peter Segal : 6
# Raja Gosnell : 6
# J.J. Abrams : 5
# Sam Mendes : 5
# Lana Wachowski : 5
# Lilly Wachowski : 5
# Chris Columbus : 5
# Peyton Reed : 5
# ...

# %%
# Создаем dataframe, который содержит перечень всех студий с их ID
pd.DataFrame(data['production_companies'].str.split('|').tolist(),index=data['imdb_id']).stack().reset_index([0])
# Используем созданный ранее dataframe all_genres, который содержит перечень всех жанров с их ID
all_genres=pd.DataFrame(data['genres'].str.split('|').tolist(),index=data['imdb_id']).stack().reset_index([0])
# Создаем dataframe, который содержит перечень всех ID с их доходом
all_profit=pd.DataFrame(data['revenue'].tolist(),index=data['imdb_id']).stack().reset_index([0])
# Объединяем два dataframe
data_join_companies_genres = all_production_companies.merge(all_genres, on='imdb_id', how='left')
data_join_companies_genres_revenue = data_join_companies_genres.merge(all_profit, on='imdb_id', how='left')
# Переименовываем колонки
data_join_companies_genres_revenue.columns = ['id','companies','genres', 'revenue']
# Фильтруем таблицу по жанру
data_join_companies_genres_revenue[data_join_companies_genres_revenue['genres'] == 'Comedy']
# Создаем сводную таблицу с компанией и суммой ее дохода
comedy=data_join_companies_genres_revenue.pivot_table(index='companies',values='revenue', aggfunc='sum')
# Фильтруем таблицу по доходу
comedy.sort_values(['revenue'],ascending=False).reset_index().head(1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-121-cfc6ece93df9> in <module>
#       6 all_profit=pd.DataFrame(data['revenue'].tolist(),index=data['imdb_id']).stack().reset_index([0])
#       7 # Объединяем два dataframe
# ----> 8 data_join_companies_genres = all_production_companies.merge(all_genres, on='imdb_id', how='left')
#       9 data_join_companies_genres_revenue = data_join_companies_genres.merge(all_profit, on='imdb_id', how='left')
#      10 # Переименовываем колонки
#
# NameError: name 'all_production_companies' is not defined

# %%
#filter by comedy,production,profit. rearrange, group, count profit
data['profit']=data.revenue-data.budget
df22=data.loc[:,['profit','production_companies','genres']].copy()
df22=df22[df22.genres.str.contains('Comedy',na=False)]
df22=pd.DataFrame(df22['production_companies'].str.split('|').tolist(),index=df22['profit']).stack().reset_index([0])
df22.rename(columns={0:'production'},inplace=True)
df22=df22.reset_index(drop=True)
df22=df22[df22.production.str.contains('Warner Bros|Universal|Columbia Pictures|Paramount Pictures|Walt Disney',na=False)]
df22=df22.groupby('production').sum().sort_values(by='profit',ascending=False).reset_index()
pd.set_option('display.max_row',100)
df22.head(20)
worterbuch={}
liste=['Warner Bros','Universal','Columbia Pictures','Paramount Pictures','Walt Disney']
for i in liste:
    df=df22[df22.production.str.contains(i,na=False)]
    sumishe=df['profit'].sum()
    worterbuch[i]=sumishe

max(worterbuch,key=worterbuch.get)

#worterbuch


# answer - 5
